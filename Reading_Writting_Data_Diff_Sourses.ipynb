# %%
import pandas as pd

# %%
schema_df = pd.read_csv("data/Survey_results_schema.csv")

# %%
df = pd.read_csv("data/Survey_results_public.csv")

# %%
pd.set_option("display.max_columns",85)
pd.set_option("display.max_rows",85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
fill = (df['Country'] == 'India')

# %%
filt = (df['Country'] == 'Canada')

# %%
canada = df.loc[filt]

# %%
canada
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 11             12             I am a student who is learning to code       No
# 20             21                        I code primarily as a hobby      Yes
# 30             31             I am a student who is learning to code       No
# 36             37                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88771       69741                                                NaN      Yes
# 88801       75496                                                NaN      Yes
# 88838       82007                                                NaN       No
# 88855       85182                                                NaN       No
# 88878       88377                                                NaN      Yes
#
# ...

# %%
India_df = df.loc[fill]

# %%
India_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 11             12             I am a student who is learning to code       No
# 20             21                        I code primarily as a hobby      Yes
# 30             31             I am a student who is learning to code       No
# 36             37                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88771       69741                                                NaN      Yes
# 88801       75496                                                NaN      Yes
# 88838       82007                                                NaN       No
# 88855       85182                                                NaN       No
# 88878       88377                                                NaN      Yes
#
# ...

# %%
India_df.to_csv("data/Modified.csv")

# %%
India_df.to_csv("data/new.tsv",sep='\t')

# %%
India_df.to_excel("data/Modified.xlsx")

# %%
import sqlalchemy 
from sqlalchemy import create_engine
import psycopg2

# %%
engine =create_engine('mysql+pymysql://root:@localhost:3306/school')

# %%
India_df.to_sql('semple_Table',engine)
# Out:
# C:\Users\Keshav\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\sql.py:1333: UserWarning: The provided table name 'semple_Table' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
can =sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/school')

# %%
canada.to_sql('canada_scack_data',can)
